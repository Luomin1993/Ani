# %%
import pylab
import matplotlib as mpl
import pandas as pd
import scipy as scp
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.interpolate import UnivariateSpline
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 18})
from scipy.stats import f_oneway

#new stuff
from scipy.stats import friedmanchisquare
from scipy.stats import chisqprob
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <h1> Example usage of Friedman Test using a uniform distribution </h1>

# %%
#Friendman test with uniform distrubuation
chi2, p = friedmanchisquare(np.random.uniform(0,10,100),np.random.uniform(0,10,100),np.random.uniform(0,10,100))
print('p value = '+'{:0.2f}'.format(p*100)+'%')
#p value of 5 to 90 % is good agreement
# Out:
# p value = 88.69%

# %% [markdown]
# <h3> This loads in the data </h3>

# %%
Ani=pd.read_excel('/Users/attiladobi/Documents/Ani/sept_oct2013.xlsx',skiprows=0)
#Ani=pd.read_excel('data/sept_oct2013.xlsx',skiprows=0)
Time=array(Ani['Time'].T,dtype='datetime64')
Ani['Hour']=pd.DatetimeIndex(Ani['Time']).hour #allows to sort by hours of the day
Ani['Day']=pd.DatetimeIndex(Ani['Time']).day #sort by hours of the day
Ani['Month']=pd.DatetimeIndex(Ani['Time']).month #sort by hours of the day

# %% [markdown]
# <h1> List the available keys </h1>

# %%
Ani.keys()
# Out:
# Index([ u'Time',   u'TS2',   u'HS2',   u'DS2',  u'TSh6',  u'HSh6',  u'DSh6',
#         u'TSh7',  u'HSh7',  u'DSh7',  u'TS10',  u'HS10',  u'DS10', u'TSh16',
#        u'HSh16', u'DSh16', u'TSh17',  u'Sh17', u'DSh17',  u'TS19',  u'HS19',
#         u'DS19', u'TSh19', u'HSh19', u'DSh19',  u'TS27',  u'HS27',  u'DS27',
#         u'TS29',  u'HS29',  u'DS29',  u'TS32',  u'HS32',  u'DS32', u'TSh33',
#        u'HSh33', u'DSh33',  u'TS34',  u'HS34',  u'DS34', u'TSh35', u'HSh35',
#        u'DSh35',  u'TS37',  u'HS37',  u'DS37', u'TSh42', u'HSh42', u'DSh42',
#          u'TK5',   u'HK5',   u'DK5',   u'TK8',   u'HK8',   u'DK8',  u'Hour'],
#       dtype='object')

# %% [markdown]
# <h1> Pull out temperature data by hour, build a dictionary of all sensors </h1>

# %%
vals_hour=[]
hours=np.arange(0,24)
for hour in hours:
    vals=[]
    for key in Ani.keys():
        if not (key == 'Time'): #skip the time key
            vals.append(Ani[key].loc[Ani['Hour']==hour].mean())
    vals_hour.append(vals)
#convert to a numpy array
vals_hour=np.array(vals_hour)
Ani_hourly=dict((key, vals_hour[:,ii]) for ii, key in enumerate(Ani.keys()[1:]))

# %% [markdown]
# <h1> The previous code is brute force, much simpler using groupy in pandas </h1>

# %%
#This will group by hour and find the mean for each sensor (same as above)
Ani_hourly=Ani.groupby('Hour').mean()

# %%
Ani_hourly
# Out:
#             TS2        HS2       DS2       TSh6       HSh6      DSh6  \
# Hour
# 0      9.507051  64.657692  3.099615   9.516667  63.911538  2.956154
# 1      8.625641  67.332692  2.824872   8.638462  66.707051  2.722564
# 2      7.824359  69.430128  2.495513   7.888462  68.701923  2.425256
# 3      6.879487  71.608333  2.022821   7.034615  70.430128  1.956154
# 4      6.221795  74.169872  1.886026   6.318590  72.755769  1.722179
# 5      6.000000  75.017337  1.825798   6.090153  73.920250  1.720666
# 6      5.395455  75.840152  1.395909   5.514394  74.348485  1.245606
# 7      6.038636  74.566667  1.746515   6.202273  73.477273  1.711667
# 8     14.864394  55.434091  4.922576  11.419697  62.696970  4.191970
# 9     23.585606  37.623485  6.393333  15.642965  52.060514  5.287595
# 10    31.337179  24.416667  6.687692  21.331410  37.946795  5.415513
# 11    38.271154  16.211538  6.373333  26.198077  27.279487  4.581154
# ...

# %% [markdown]
# <h1> Now, we will want to groupy hour on a daily and monthly basis </h1>

# %%
#This will group by hour and find the mean for each sensor (same as above)
Ani_hourly_all=Ani.loc[(Ani.Hour>10) & (Ani.Hour<15)].groupby(['Month','Day','Hour']).mean()
#~isnan(Ani.TS2) & ~isnan(Ani.TS10) & ~isnan(Ani.TS19) & ~isnan(Ani.TS27)& ~isnan(Ani.TS37)

# %%
Ani_hourly_all
# Out:
#                       TS2        HS2        DS2       TSh6       HSh6  \
# Month Day Hour
# 9     24  11          NaN        NaN        NaN        NaN        NaN
#           12          NaN        NaN        NaN        NaN        NaN
#           13          NaN        NaN        NaN        NaN        NaN
#           14          NaN        NaN        NaN        NaN        NaN
#       25  11    41.191667  11.066667   4.936667  26.350000  18.933333
#           12    46.150000   9.633333   6.623333  29.783333  17.391667
#           13    50.116667   7.683333   6.266667  32.908333  13.908333
#           14    44.116667   8.425000   3.171667  33.258333  13.066667
#       26  11    35.283333  22.091667  10.261667  20.425000  45.491667
#           12    43.058333  14.433333  10.136667  26.066667  31.758333
#           13    49.225000   8.625000   7.175000  32.108333  17.516667
#           14    47.833333   5.941667   0.995000  33.566667  10.991667
# ...

# %% [markdown]
# <h1> Here we'll do the Friendman test broken down by each sensor </h1>

# %% [markdown]
# <h1> Setup time range </h1>

# %%
#set hour range
time_start=10
time_end =15
cut=range(time_start,time_end)

# %% [markdown]
# <h1> Friedman test of all the sun back sensors </h1>

# %%
chi2, p = friedmanchisquare(Ani_hourly['TS2'][cut],Ani_hourly['TS10'][cut],Ani_hourly['TS19'][cut])
print ('chi^2 =',chi2,' p= ', p)
print('p value = '+'{:0.2f}'.format(p*100)+'%')
# Out:
# ('chi^2 =', 6.4000000000000057, ' p= ', 0.040762203978366107)
# p value = 4.08%

# %% [markdown]
# <h2> Sun back, the entire data set averaged every hour </h2>

# %%
chi2, p = friedmanchisquare(Ani_hourly_all['TS2'],Ani_hourly_all['TS10'],Ani_hourly_all['TS19'])
print ('chi^2 =',chi2,' p= ', p)
print('p value = '+'{:0.2f}'.format(p*100)+'%')
# Out:
# ('chi^2 =', 40.333333333333258, ' p= ', 1.7447288735863923e-09)
# p value = 0.00%

# %% [markdown]
# <h1> Sun front, hourly average </h1>

# %%
chi2, p = friedmanchisquare(Ani_hourly['TS27'][cut],Ani_hourly['TS29'][cut],Ani_hourly['TS32'][cut],\
                            Ani_hourly['TS34'][cut],Ani_hourly['TS37'][cut])
print ('chi^2 =',chi2,' p= ', p)
print('p value = '+'{:0.2f}'.format(p*100)+'%')
#hmm, these are quite different
# Out:
# ('chi^2 =', 19.359999999999999, ' p= ', 0.00066772966031508044)
# p value = 0.07%

# %%
chi2, p = friedmanchisquare(Ani_hourly_all['TS27'],Ani_hourly_all['TS29'],Ani_hourly_all['TS32'],\
                            Ani_hourly_all['TS34'],Ani_hourly_all['TS37'])
print ('chi^2 =',chi2,' p= ', p)
print('p value = '+'{:0.2f}'.format(p*100)+'%')
#hmm, these are quite different
# Out:
# ('chi^2 =', 115.94810009267844, ' p= ', 3.9160743196450137e-24)
# p value = 0.00%

# %%
chi2, p = friedmanchisquare(Ani_hourly_all['TS27'],Ani_hourly_all['TS29'],Ani_hourly_all['TS37'])
print ('chi^2 =',chi2,' p= ', p)
print('p value = '+'{:0.2f}'.format(p*100)+'%')
# Out:
# ('chi^2 =', 10.037037037036953, ' p= ', 0.0066143184446752915)
# p value = 0.66%

# %% [markdown]
# <h1> How different three sun-back sensors from the five sun-front sensors? </h1>

# %%
chi2, p = friedmanchisquare(Ani_hourly['TS2'][cut],Ani_hourly['TS10'][cut],Ani_hourly['TS19'][cut]\
                           ,Ani_hourly['TS27'][cut],Ani_hourly['TS29'][cut],Ani_hourly['TS32'][cut]\
                            ,Ani_hourly['TS34'][cut],Ani_hourly['TS37'][cut] )
print ('chi^2 =',chi2,' p= ', p)
print('p value = '+'{:0.5f}'.format(p*100)+'%')
# Out:
# ('chi^2 =', 33.0, ' p= ', 2.6476442940650662e-05)
# p value = 0.00265%

# %% [markdown]
# <h1> How different three sun-back sensors from the average of sun-front </h1>

# %%
chi2, p = friedmanchisquare(Ani_hourly['TS2'][cut],Ani_hourly['TS10'][cut],Ani_hourly['TS19'][cut]\
                           ,mean( (Ani_hourly['TS27'][cut],Ani_hourly['TS29'][cut],Ani_hourly['TS32'][cut]\
                            ,Ani_hourly['TS34'][cut],Ani_hourly['TS37'][cut]),0) )
print ('chi^2 =',chi2,' p= ', p)
print('p value = '+'{:0.4f}'.format(p*100)+'%')
# Out:
# ('chi^2 =', 12.840000000000003, ' p= ', 0.0049957060439281822)
# p value = 0.4996%

# %% [markdown]
# <h1 style="color:red;"> In the following we do it in groups, and also with a Chi^2 test </h1>

# %% [markdown]
# <h3> Friedman test for the means of the sensors broken up into four catigories
#    <ul>
#     <li> sun_ave_front </li>
#     <li> sun_ave_back </li>
#     <li> shade_ave_all </li>
#     <li> control </li>
#    </ul>
# </h3>

# %% [markdown]
# <h1> Define function to sort data time of day, return means and standard deviation </h1>

# %%
def get_ave_values(str1='T'):
    shade_ave_all=[]
    sun_ave_front=[]
    sun_ave_back=[]
    con_ave_all=[]
    shade_std_all=[]
    sun_std_front=[]
    sun_std_back=[]
    con_std_all=[]
    hours=np.arange(0,24)
    for hour in hours:
        means_sun_back=[]
        means_sun_front=[]
        means_shade=[]
        means_con=[]
        for key in Ani.keys():
            if (key[0:3]==str1+'Sh'):
                means_shade.append(Ani[key].loc[Ani['Hour']==hour].mean())
                #print(key,Ani[key].loc[Ani['Hour']==hour].mean())
            elif ((key[0:3]==str1+'S2') | (key[0:4]==str1+'S10') | (key[0:4]==str1+'S19') ) :
                means_sun_back.append(Ani[key].loc[Ani['Hour']==hour].mean())
            elif (key[0:2]==str1+'S'):
                means_sun_front.append(Ani[key].loc[Ani['Hour']==hour].mean())
            elif (key[0:2]==str1+'K'):
                means_con.append(Ani[key].loc[Ani['Hour']==hour].mean())
        shade_ave_all.append(mean(means_shade))
        shade_std_all.append(std(means_shade))
        sun_ave_back.append(mean(means_sun_back))
        sun_std_back.append(std(means_sun_back))
        sun_ave_front.append(mean(means_sun_front))
        sun_std_front.append(std(means_sun_front))
        con_ave_all.append(mean(means_con))
        con_std_all.append(std(means_con))
    return sun_ave_back, sun_std_back, sun_ave_front, sun_std_front, shade_ave_all, shade_std_all, con_ave_all, con_std_all

# %% [markdown]
# <h1> Test hypothosis that three independent measurements are the same. Below: select the time range and compute the mean and standard deviation</h1>

# %%
sun_ave_back, sun_std_back, sun_ave_front, sun_std_front, shade_ave_all, shade_std_all, con_ave_all, con_std_all = get_ave_values('T')

# %%
#set time range
start_h=10
end_hour=15
hour_diff=end_hour-start_h 

sun_back_test=np.array([])
sun_front_test=np.array([])
shade_test=np.array([])
cont_test=np.array([])
std_sun_back_test=np.array([])
std_sun_front_test=np.array([])
std_shade_test=np.array([])
std_cont_test=np.array([])


for hour in range(start_h,end_hour):
    sun_back_test= hstack((sun_back_test,sun_ave_back[hour]))
    sun_front_test= hstack((sun_front_test,sun_ave_front[hour]))
    shade_test= hstack((shade_test,shade_ave_all[hour]))
    cont_test= hstack((cont_test,con_ave_all[hour]))
    #get std
    std_sun_back_test= hstack((std_sun_back_test,sun_std_back[hour]))
    std_sun_front_test= hstack((std_sun_front_test,sun_std_front[hour]))
    std_shade_test= hstack((std_shade_test,shade_std_all[hour]))
    std_cont_test= hstack((std_cont_test,con_std_all[hour]))

# %% [markdown]
# <h1> Friedman test... Testing weather or not three independent measurements are consistent with each other </h1>

# %%
# here we test the mean of sun_back, sun_front, and the control averaged over hour
chi2, p = friedmanchisquare(sun_back_test,sun_front_test,sun_back_test)
print ('chi^2 =',chi2,' p= ', p)

#if we want to test the difference between only two measurements have to use a chi^2 test taking one as the theory and the other as the experiment:
#the degrees of freedom are the number of data points - 1 for the averaging. Form that you can calulate the p value.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-199-0b2c69f8c028> in <module>()
#       1 # here we test the mean of sun_back, sun_front, and the control averaged over hour
# ----> 2 chi2, p = friedmanchisquare(sun_back_test,sun_back_test)
#       3 print ('chi^2 =',chi2,' p= ', p)
#       4
#       5 #if we want to test the difference between only two measurements have to use a chi^2 test taking one as the theory and the other as the experiment:
#
# /Users/attiladobi/anaconda/lib/python2.7/site-packages/scipy/stats/stats.pyc in friedmanchisquare(*args)
#    4431     k = len(args)
#    4432     if k < 3:
# -> 4433         raise ValueError('\nLess than 3 levels.  Friedman test not appropriate.\n')
#    4434
#    4435     n = len(args[0])
#
# ValueError:
# Less than 3 levels.  Friedman test not appropriate.

# %% [markdown]
# <h2> let's do a Chi^2 test between the sun_back and sun_front. Fine in limit of average over 1000+ data points where the central value and standard deviation are well defined </h2>

# %%
#take the sun back as the experiment and sun_front as the theoretical expectation
#method: X^2 = sum( ((Fe-Ft)^2/sigma^2 )

chi2= sum( (sun_front_test-sun_back_test)**2/(std_sun_back_test**2 + std_sun_front_test**2) )
p_val = chisqprob(chi2, hour_diff-1)

print('chi^2 =', chi2, ' p value of chi^2 test = ', p_val)
# Out:
# ('chi^2 =', 14.025913256561843, ' p value of chi^2 test = ', 0.0072128089106260496)

# %%
#Compare Shade to Sun-front
#method: X^2 = sum( ((Fe-Ft)^2/sigma^2 )

chi2= sum( (sun_front_test-shade_test)**2/(std_sun_back_test**2 + std_shade_test**2) )
p_val = chisqprob(chi2, hour_diff-1)

print('chi^2 =', chi2, ' p value of chi^2 test = ', p_val)
# Out:
# ('chi^2 =', 12.5643374367781, ' p value of chi^2 test = ', 0.013612864698142775)

# %%
f_oneway(sun_front_test,sun_back_test)
# Out:
# F_onewayResult(statistic=2.4837766514169384, pvalue=0.15367533169898215)
