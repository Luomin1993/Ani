# %%
import pylab
import matplotlib as mpl
import pandas as pd
import scipy as scp
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 18})
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
Ani=pd.read_excel('/Users/attiladobi/Documents/Ani/Subsole sept 2013.xlsx',skiprows=2,header=None)

# %%
names=['Celsius','Humidity','DP']

# %%
Ani.rename(columns={0:'Time'}, inplace=True)
for ii, name in enumerate(names*16):
    Ani.rename(columns={ii+1:name}, inplace=True)

# %%
# first three sensors are sun, thress shadow, two sun, one shadow, two sun, two shadow, one sun, two shadow, 
# 3 and 14 are controls 26.9.2013 12:00:00

# %%
Time=array(Ani['Time'].T,dtype='datetime64')
Temps=array(Ani['Celsius'].T)

# %%
plt.plot_date(Time[1:-10],Temps[0][1:-10],'-b',alpha=0.7,linewidth=4)
plt.plot_date(Time[1:-10],Temps[1][1:-10],'--r',alpha=0.5)
plt.plot_date(Time[1:-10],Temps[2][1:-10],'-k',alpha=0.8)
ax = gca()
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%d %b\n%Y'))

# %% [markdown]
# <h1> Normal Data :) </h1>

# %%
Ani=pd.read_excel('/Users/attiladobi/Documents/Ani/sept_oct2013.xlsx',skiprows=0)

# %%
Time=array(Ani['Time'].T,dtype='datetime64')

# %%
Ani['Hour']=pd.DatetimeIndex(Ani['Time']).hour

# %%
Ani['TS2'].loc[Ani['Hour']==12]
# Out:
# 120       NaN
# 121       NaN
# 122       NaN
# 123       NaN
# 124       NaN
# 125       NaN
# 126       NaN
# 127       NaN
# 128       NaN
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# 133       NaN
# 134       NaN
# 135       NaN
# 136       NaN
# 137       NaN
# 138       NaN
# 139       NaN
# 140       NaN
# 141       NaN
# 142       NaN
# 143       NaN
# 144       NaN
# 145       NaN
# 146       NaN
# 147       NaN
# 148       NaN
# 149       NaN
#          ...
# 18409    40.0
# 18410    40.0
# 18411    40.0
# 18412    39.5
# 18413    39.5
# 18414    39.5
# 18415    39.5
# 18416    39.0
# 18417    39.0
# 18418    39.0
# 18419    39.5
# 18420    39.5
# 18421    40.0
# 18422    40.0
# 18423    40.0
# 18424    40.0
# 18425    39.5
# 18426    39.0
# 18427    38.5
# 18428    38.0
# 18429    38.0
# 18430    38.0
# 18431    38.0
# 18432    37.5
# 18433    37.5
# 18434    37.5
# 18435    37.0
# 18436    37.0
# 18437    37.5
# 18438    38.0
# ...

# %%
vals=[]
for key in Ani.keys():
    if (key[0:2]=='TK') | (key[0:2]=='TS'):
        vals.append(Ani[key].loc[Ani['Hour']==23].mean())
        print(key,Ani[key].loc[Ani['Hour']==23].mean())
vals.reverse()
vals_hour.append(vals)
# Out:
# (u'TS2', 11.188461538461539)
# (u'TSh6', 11.15)
# (u'TSh7', 11.421794871794871)
# (u'TS10', 11.280952380952382)
# (u'TSh16', 11.198076923076924)
# (u'TSh17', 11.33525641025641)
# (u'TS19', 11.170138888888889)
# (u'TSh19', 11.328205128205129)
# (u'TS27', 11.265277777777778)
# (u'TS29', 11.330952380952381)
# (u'TS32', 10.796428571428571)
# (u'TSh33', 11.346794871794872)
# (u'TS34', 10.927976190476191)
# (u'TSh35', 11.291025641025641)
# (u'TS37', 10.694166666666666)
# (u'TSh42', 12.058974358974359)
# (u'TK5', 10.679166666666667)
# (u'TK8', 9.2277777777777779)

# %%
vals_hour=[]
hours=np.arange(0,24)
for hour in hours:
    vals=[]
    for key in Ani.keys():
        if (key[0:2]=='TK') | (key[0:2]=='TS'):
            vals.append(Ani[key].loc[Ani['Hour']==hour].mean())
            #print(key,Ani[key].loc[Ani['Hour']==hour].mean())
    vals.reverse()
    vals_hour.append(vals)
vals_hour
savetxt('Ani_temp.txt',vals_hour)

# %%
vals
# Out:
# [9.2277777777777779,
#  10.679166666666667,
#  12.058974358974359,
#  10.694166666666666,
#  11.291025641025641,
#  10.927976190476191,
#  11.346794871794872,
#  10.796428571428571,
#  11.330952380952381,
#  11.265277777777778,
#  11.328205128205129,
#  11.170138888888889,
#  11.33525641025641,
#  11.198076923076924,
#  11.280952380952382,
#  11.421794871794871,
#  11.15,
#  11.188461538461539]

# %%
for key in Ani.keys():
    if key[0:2]=='HS':
        plt.plot_date(Time,Ani[key],alpha=0.5,linewidth=1,markersize=2)
xlim(['2013, 09 , 25','2013, 10 , 2'])
legend()
ylabel('Temp (Sun)')
ax = gca()
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%d %b\n%Y'))

# %%
for key in Ani.keys():
    if key[0:1]=='H':
        plt.plot_date(Time,Ani[key],alpha=0.5,linewidth=.5,markersize=1)

# %%
#cut in time:
Ani.loc[Ani['Time'] > '2013, 10 , 29']
# Out:
#                      Time   TS2   HS2   DS2  TSh6  HSh6  DSh6  TSh7  HSh7  \
# 17659 2013-10-29 00:00:50  14.0  58.0   5.9  14.0  56.0   5.4  14.5  55.0
# 17660 2013-10-29 00:01:50  14.0  58.0   5.9  14.0  56.0   5.4  14.0  55.5
# 17661 2013-10-29 00:02:50  13.5  58.0   5.4  14.0  56.0   5.4  14.0  55.0
# 17662 2013-10-29 00:03:50  13.5  58.5   5.5  13.5  56.0   4.9  14.0  55.0
# 17663 2013-10-29 00:04:50  13.5  59.0   5.7  13.5  56.5   5.0  14.0  55.0
# 17664 2013-10-29 00:05:50  13.5  59.5   5.8  13.5  57.0   5.2  14.0  55.5
# 17665 2013-10-29 00:06:50  13.5  60.0   5.9  13.5  57.5   5.3  14.0  56.5
# 17666 2013-10-29 00:07:50  13.5  60.5   6.0  13.5  58.0   5.4  14.0  56.5
# 17667 2013-10-29 00:08:50  13.5  61.0   6.1  13.5  58.5   5.5  14.0  57.0
# 17668 2013-10-29 00:09:50  13.5  60.5   6.0  13.5  60.5   6.0  14.0  58.0
# 17669 2013-10-29 00:10:50  13.5  59.5   5.8  13.5  60.5   6.0  14.0  58.0
# 17670 2013-10-29 00:11:50  13.5  61.0   6.1  13.5  60.5   6.0  13.5  58.5
# ...

# %%
(Ani.columns,'TS')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-316-b36207956d26> in <module>()
# ----> 1 ismeber(Ani.columns,'TS')
#
# NameError: name 'ismeber' is not defined

# %%
from mpl_toolkits.basemap import Basemap

# %%
map=Basemap()

# %%
map.drawcoastlines()
map.fillcontinents()

# %%
x,y=map()
cs=map.contour

# %%
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
m.bluemarble()
plt.show()

# %%
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=79.,lat_2=80,lat_0=78,lon_0=45.)
m.etopo()
plt.show()
